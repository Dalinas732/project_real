# %%
from class_ai import Temperature_Data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("cleandata.xlsx", sheet_name=None)
tp = Temperature_Data(data)
years = tp.years
years = years[::-1]

# %%
dec15 = tp.collect_day(12,15,0)
tp.plot_hist(dec15,"December 15th")
march15 = tp.collect_day(3,15,0)
tp.plot_hist(march15,"March 15th")
