# %%
from expected_script import *

# %%
#####################################
month = 5             # 1->12
mode = 0              # 0,1,2 -> high,avg,low
#####################################
avg_temps(month,mode)
