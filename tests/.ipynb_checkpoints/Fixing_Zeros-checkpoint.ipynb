# %%
"""
First attempt to fix zeros for all years. Still a work in progress. Makes a new sheet for each year and I do not want this.
"""
from DataCollection import Temperature_Data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pip install xlsxwriter
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xlsxwriter in /home/nicho732/.local/lib/python3.11/site-packages (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
data = pd.read_excel("cleandata.xlsx", sheet_name=None)
tp = Temperature_Data(data)
years = tp.years

# %%
def check_zeros(data):
    for i in range (data.size-1):
        if data[i] == 0:
            return True
    return False

# %%
# Define the Excel filename
file_name = "no_zeros_data.xlsx"

# %%
months = np.arange(12) + 1
for year in years: ### Indexes through all years
    df = tp.dfs[year].astype(float)
    for month in months: ### Goes through all months in a given year
        lows = tp.collect_month(month,year,"low")
        avgs = tp.collect_month(month,year,"average")
        highs = tp.collect_month(month,year,"high")
        tp.check_length_of_month(lows.size,month,year)
        tp.check_length_of_month(avgs.size,month,year)
        tp.check_length_of_month(highs.size,month,year)
        if check_zeros(lows):
            print(f"Month = {month}. Year = {year}")
            for i in range(lows.size):
                if lows[i] == 0:
                    newlow = round(2*avgs[i] - highs[i],3)
                    lows[i] = newlow
                    assert lows[i] == newlow, f"The low was not changed for month = {month} and index = {i}."     
        pd_lows = np.append(lows,[float(np.nan)]*(31-lows.size))
        df.iloc[:,(3*month-1)] = pd_lows
    with pd.ExcelWriter(file_name, engine='xlsxwriter') as writer: ### Writes a new sheet. 
        df.to_excel(writer, sheet_name=year, index=False)
# Out:
# Month = 1. Year = 2024
# Month = 5. Year = 2024
# Month = 10. Year = 2024
# Month = 7. Year = 2023
# Month = 9. Year = 2023
# Month = 1. Year = 2022
# Month = 5. Year = 2022
# Month = 2. Year = 2021
# Month = 3. Year = 2021
# Month = 2. Year = 2020
# Month = 3. Year = 2020
# Month = 9. Year = 2020
# Month = 12. Year = 2020
# Month = 3. Year = 2019
# Month = 6. Year = 2019
# Month = 7. Year = 2019
# Month = 8. Year = 2019
# Month = 9. Year = 2019
# Month = 1. Year = 2018
# Month = 6. Year = 2018
# Month = 9. Year = 2018
# Month = 12. Year = 2018
# Month = 9. Year = 2017
# Month = 11. Year = 2017
# Month = 1. Year = 2016
# Month = 2. Year = 2016
# Month = 3. Year = 2016
# Month = 7. Year = 2016
# Month = 1. Year = 2015
# Month = 2. Year = 2015
# Month = 3. Year = 2015
# Month = 6. Year = 2015
# Month = 2. Year = 2014
# Month = 6. Year = 2014
# Month = 9. Year = 2014
# Month = 10. Year = 2014
# Month = 2. Year = 2013
# Month = 6. Year = 2013
# Month = 9. Year = 2013
# Month = 12. Year = 2013
# Month = 2. Year = 2011
# Month = 3. Year = 2009
# Month = 8. Year = 2009
# Month = 9. Year = 2009
# Month = 11. Year = 2009
# Month = 12. Year = 2009
# Month = 2. Year = 2008
# Month = 8. Year = 2008
# Month = 11. Year = 2008
# Month = 12. Year = 2008
# Month = 3. Year = 2007
# Month = 8. Year = 1982
# Month = 9. Year = 1982
# Month = 10. Year = 1982
# Month = 11. Year = 1982
# Month = 12. Year = 1982
# Month = 1. Year = 1981
# Month = 2. Year = 1981
# Month = 3. Year = 1981
# Month = 4. Year = 1981
# Month = 5. Year = 1981
# Month = 6. Year = 1981
# Month = 7. Year = 1981
# Month = 8. Year = 1981
# Month = 9. Year = 1981
# Month = 10. Year = 1981
# Month = 11. Year = 1981
# Month = 12. Year = 1981
# Month = 1. Year = 1980
# Month = 2. Year = 1980
# Month = 3. Year = 1980
# Month = 4. Year = 1980
# Month = 5. Year = 1980
# Month = 6. Year = 1980
# Month = 7. Year = 1980
# Month = 8. Year = 1980
# Month = 9. Year = 1980
# Month = 10. Year = 1980
# Month = 11. Year = 1980
# Month = 12. Year = 1980
# Month = 1. Year = 1979
# Month = 2. Year = 1979
# Month = 3. Year = 1979
# Month = 4. Year = 1979
# Month = 5. Year = 1979
# Month = 6. Year = 1979
# Month = 7. Year = 1979
# Month = 8. Year = 1979
# Month = 9. Year = 1979
# Month = 10. Year = 1979
# Month = 11. Year = 1979
# Month = 12. Year = 1979
# Month = 1. Year = 1978
# Month = 2. Year = 1978
# Month = 3. Year = 1978
# Month = 4. Year = 1978
# Month = 5. Year = 1978
# Month = 6. Year = 1978
# Month = 7. Year = 1978
# Month = 8. Year = 1978
# Month = 9. Year = 1978
# Month = 10. Year = 1978
# Month = 11. Year = 1978
# Month = 12. Year = 1978
# Month = 1. Year = 1977
# Month = 2. Year = 1977
# Month = 3. Year = 1977
# Month = 4. Year = 1977
# Month = 5. Year = 1977
# Month = 6. Year = 1977
# Month = 7. Year = 1977
# Month = 8. Year = 1977
# Month = 9. Year = 1977
# Month = 10. Year = 1977
# Month = 11. Year = 1977
# Month = 12. Year = 1977
# Month = 1. Year = 1976
# Month = 2. Year = 1976
# Month = 3. Year = 1976
# Month = 4. Year = 1976
# Month = 5. Year = 1976
# Month = 6. Year = 1976
# Month = 7. Year = 1976
# Month = 8. Year = 1976
# Month = 9. Year = 1976
# Month = 10. Year = 1976
# Month = 11. Year = 1976
# Month = 12. Year = 1976
# Month = 1. Year = 1975
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 8
#       6 avgs = tp.collect_month(month,year,"average")
#       7 highs = tp.collect_month(month,year,"high")
# ----> 8 tp.check_length_of_month(lows.size,month,year)
#       9 tp.check_length_of_month(avgs.size,month,year)
#      10 tp.check_length_of_month(highs.size,month,year)
#
# File ~/CMSE802/Project/DataCollection.py:30, in Temperature_Data.check_length_of_month(self, count, month, year)
#      28     else:
#      29         correct = 28
# ---> 30         assert count == correct, f"Number of days in month = {month} year = {year}. {count} != correct {correct}."
#      31 else:
#      32     raise ValueError(f"Month = {month} was not read between 1-12. Year = {year}.")
#
# AssertionError: Number of days in month = 2 year = 1975. 29 != correct 28.
