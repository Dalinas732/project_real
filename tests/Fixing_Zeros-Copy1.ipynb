# %%
"""
First attempt to fix zeros for all years. Still a work in progress. Makes a new sheet for each year and I do not want this.
"""
from DataCollection_test import Temperature_Data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("cleandata.xlsx", sheet_name=None)
tp = Temperature_Data(data)
years = tp.years

# %%
lows = tp.collect_month(2,1980,"low")
lows
# Out:
# array([-4. ,  4. , -1. ,  2. ,  0.4, 12.2, 11.2,  3. , 13.4,  1.6, 12.6,
#         6.8, 11.8, 21.6,  6.4,  8. ,  2.4,  9.4, 15.4, 20.6, 23. , 11.4,
#         0. ,  8. ,  5.4, -1. , 10.2,  7. , -6. ])

# %%
lows = tp.collect_day(2,12,mode="low")
tp.plot_hist(lows)
